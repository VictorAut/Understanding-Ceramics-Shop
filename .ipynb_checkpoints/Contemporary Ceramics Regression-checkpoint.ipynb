# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.model_selection import train_test_split # For splitting the data for testing purposes
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import TransformedTargetRegressor

import seaborn as sns # For visualisations
import statsmodels.api as sm # For linear regression modelling
from statsmodels.graphics.gofplots import qqplot

from statsmodels.graphics.api import abline_plot # For visualling evaluating predictions
import warnings
warnings.filterwarnings('ignore')

# %%
#import the full, labelled data set
pots = pd.read_csv('Pots_clean_labelled.csv')
pots.head(1)
# Out:
#   productcode  price       maker                            name  \
# 0   AM470Y165   47.0  Andy Mason  ovalled bowl cream satin motif
#
#                                          description  height  width  depth  \
# 0  this stoneware bowl is wheel-thrown with a cre...     8.0   25.5   22.0
#
#    materials technique    firing decoration category
# 0  Stoneware    Thrown  Electric      Glaze    first

# %%
pots_encoded = pd.get_dummies(
                                pots.drop(columns=['productcode', 'name', 'maker', 'description']),
                                drop_first=True #Always drop one category as information is encoded in subsequent vars
                            )
pots_encoded.columns
# Out:
# Index(['price', 'height', 'width', 'depth', 'materials_Earthenware',
#        'materials_Porcelain', 'materials_Stoneware', 'technique_Thrown',
#        'firing_Gas', 'firing_Raku', 'firing_Wood', 'decoration_Lustre',
#        'decoration_Sgraffito', 'decoration_Slip decoration',
#        'decoration_Terra Sigillata', 'category_first', 'category_fourth',
#        'category_second', 'category_third'],
#       dtype='object')

# %%
cols = pots_encoded.columns.drop('price')
n_cols = 6

for i in range(0, len(cols), n_cols):
    sns.pairplot(data=pots_encoded[pots_encoded['price'] < 3000], #exclude most expensive pots for visual purposes
             x_vars=cols[i:i+n_cols], 
             y_vars=['price'],
             markers='.',
             diag_kind=None, #needed to avoid broken pairplot logic (as of version 0.11.1)
             kind='reg')
    plt.show()

# %%
plt.figure(figsize=(14, 14))
sns.heatmap(abs(pots_encoded.corr()), annot = True, linewidths = 0.5, cmap = 'Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are three correlation clusters to take care of:
# 1. Width, depth
# 2. materials_Earthenware, materials_Porcelain, materials_Stoneware

# %% [markdown]
# Let's use the mean of width and depth and call it 'length'

# %%
pots_reg = pots_encoded.copy()

# %%
pots_reg['length'] = pots_reg[['depth', 'width']].mean(axis=1)
pots_reg.drop(columns=['depth', 'width'], inplace = True)

# %% [markdown]
# I will deal with the multicollinearity of the materials categorical variables using a regularized approach, if need be.

# %% [markdown]
# ## Regressor function

# %%
# regression function that returns predictions
def regressor(X, y, regression_class):

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=23)

    lin_reg = regression_class
    lin_reg.fit(X_train, y_train)

    print('intercept:', round(lin_reg.intercept_, 1))
    print('coefficients:', dict(zip(X.columns, lin_reg.coef_))) #Print out coefficients for multiple linear regression

    preds_train = lin_reg.predict(X_train)
    preds_test = lin_reg.predict(X_test)
    preds_all = lin_reg.predict(X)
    residuals = y - preds_all
    
    return X_train, X_test, y_train, y_test, preds_train, preds_test, preds_all, residuals

# calculate regression errors
def reg_errors(y_test, preds_test):
    
    mae = mean_absolute_error(y_test, preds_test)
    rmse = mean_squared_error(y_test, preds_test, squared=False)
    r2 = r2_score(y_test, preds_test)
    
    return mae, rmse, r2

#plot of regression and it's assumptions.
# func argument can be the regressor function, or any other function. log_regressor and lasso_regressor are others.
def reg_plots(func, string_description):
    
    #call regression function
    X_train, X_test, y_train, y_test, preds_train, preds_test, preds_all, residuals = func

    #call errors function
    mae, rmse, r2 = reg_errors(y_test, preds_test)
    
    fig, axes = plt.subplots(1,3,figsize=(15,6))

    #Generate a title with errors
    fig.suptitle("Regression: {}\n \
                 MAE = £{} \n \
                 RMSE = £{} \n \
                 R2 = {}".format(string_description, round(mae, 1), round(rmse, 1), round(r2,3)))

    # check assumtion: distrubtion of residuals
    sns.histplot(residuals, kde = True, bins = 100, ax=axes[0])
    axes[0].set_title("Distribution of residuals (= y - predicted)")

    #further inspection of distribution of residuals
    qqplot(residuals, line='45', fit=True, ax=axes[1])
    axes[1].set_title("Q-Q plot")

    #Inspect homoscedasticity and independence of variables
    sns.scatterplot(x=preds_all, y=residuals, ax=axes[2], alpha = 0.5, s=25)
    plt.hlines(0, min(preds_all), max(preds_all), linestyles='dashed', colors='red')
    axes[2].set_xlabel("predicted price")
    axes[2].set_ylabel("residuals")
    axes[2].set_title("residuals vs price predicted")
    
    plt.tight_layout()

# %% [markdown]
# ## Simple linear regression

# %%
X = pots_reg[['height']]
y = pots_reg['price']

reg_plots(regressor(X, y, LinearRegression()), 'simple linear regression with height')
# Out:
# intercept: -98.6
# coefficients: {'height': 29.962495391983246}

# %% [markdown]
# ## Simple linear regression (Polynomial order = 2)

# %%
X = pots_reg[['height']]
X['height2'] = X['height']**2

y = pots_reg['price']

reg_plots(regressor(X, y, LinearRegression()), 'simple linear regression with height')
# Out:
# intercept: -174.0
# coefficients: {'height': 38.934362114459645, 'height2': -0.17891223690970243}

# %% [markdown]
# Initial results with what is clearly the most important variable is already indicating that something will have to be done with the data in order to make it more appropriate for a regression analysis.
#
# To consider, and looking at the distribution of the residuals, is to apply some log-normal transformation.
#
# Additionally, I will consider stripping out the higher value pots, as it may well be that they are from a small and select number of makers only.
#
# Firstly, let's try a multiple linear regression.

# %% [markdown]
# ## Multiple linear regressions

# %%
X = pots_reg[['height', 'materials_Earthenware', 'materials_Porcelain',
       'materials_Stoneware', 'technique_Thrown', 'firing_Gas', 'firing_Raku',
       'firing_Wood', 'decoration_Lustre', 'decoration_Sgraffito',
       'decoration_Slip decoration', 'decoration_Terra Sigillata', 'length']]
y = pots_reg['price']

reg_plots(regressor(X, y, LinearRegression()), 'all independent variables')
# Out:
# intercept: -541.6
# coefficients: {'height': 24.351624392125053, 'materials_Earthenware': -107.08983939188695, 'materials_Porcelain': 66.7755208946448, 'materials_Stoneware': 234.54177341015, 'technique_Thrown': -94.78451066694207, 'firing_Gas': -59.87707990800115, 'firing_Raku': -94.86693099725642, 'firing_Wood': -94.01262399493253, 'decoration_Lustre': -34.60639881470353, 'decoration_Sgraffito': 194.32992889842743, 'decoration_Slip decoration': -18.79821942469963, 'decoration_Terra Sigillata': 556.9575507114117, 'length': 36.26693293062193}

# %% [markdown]
# ## All variables and polynomials to degree = 2

# %%
X = pots_reg[['height', 'materials_Earthenware', 'materials_Porcelain',
       'materials_Stoneware', 'technique_Thrown', 'firing_Gas', 'firing_Raku',
       'firing_Wood', 'decoration_Lustre', 'decoration_Sgraffito',
       'decoration_Slip decoration', 'decoration_Terra Sigillata', 'length']]
y = pots_reg['price']


# Define a PolynomialFeatures transformer with degree=2 and include_bias=False
poly = PolynomialFeatures(degree=2, include_bias=False)

# Fit transform the training data
X = poly.fit_transform(X)

X = pd.DataFrame(data=X, columns=poly.get_feature_names())

reg_plots(regressor(X, y, LinearRegression()), 'all independent variables')
# Out:
# intercept: 342.4
# coefficients: {'x0': -18.645086165914663, 'x1': 63.39853428980308, 'x2': -120.60607836525763, 'x3': -405.6282621269834, 'x4': -103.85922719059391, 'x5': 266.75912734223937, 'x6': 120.27506226102929, 'x7': 53.38114621792244, 'x8': 74.93556900333407, 'x9': -261.512669133919, 'x10': -118.48446765425336, 'x11': -617.5801675982875, 'x12': -14.265845317618455, 'x0^2': -0.3716260198929717, 'x0 x1': 5.451163436240989, 'x0 x2': 18.03477234811622, 'x0 x3': 39.89964759270052, 'x0 x4': 2.470060560495739, 'x0 x5': -18.705797666803996, 'x0 x6': -23.79460696830695, 'x0 x7': -19.437249570196514, 'x0 x8': 8.652598701813098, 'x0 x9': 18.264810323966614, 'x0 x10': 4.425614894047044, 'x0 x11': 340.51533481921206, 'x0 x12': 2.162971792821253, 'x1^2': 63.39853429007626, 'x1 x2': 1.3358203432289883e-12, 'x1 x3': 1.3724132941206335e-11, 'x1 x4': -126.12784899415954, 'x1 x5': 1.0516032489249483e-12, 'x1 x6': 6.707523425575346e-12, 'x1 x7': -241.0410085606435, 'x1 x8': -3.183231456205249e-12, 'x1 x9': -387.5820591934833, 'x1 x10': -2.1659934991469663, 'x1 x11': -617.5801675983026, 'x1 x12': -8.776641586556991, 'x2^2': -120.60607836569136, 'x2 x3': 1.2221335055073723e-12, 'x2 x4': 21.369850513623334, 'x2 x5': 67.42752986920253, 'x2 x6': 53.267760784656765, 'x2 x7': 168.89113182212824, 'x2 x8': 25.118375125767013, 'x2 x9': -191.0361099962638, 'x2 x10': -56.92804599565357, 'x2 x11': -3.701927653310122e-12, 'x2 x12': 10.143531337351504, 'x3^2': -405.6282621277699, 'x3 x4': 0.8987712899756684, 'x3 x5': 199.33159747304484, 'x3 x6': 67.00730147632727, 'x3 x7': 125.53102295641749, 'x3 x8': 49.81719387757536, 'x3 x9': 93.2414902994181, 'x3 x10': -298.36222460641375, 'x3 x11': 0.0, 'x3 x12': 41.00987296195703, 'x4^2': -103.85922719057673, 'x4 x5': -212.5499100268467, 'x4 x6': 53.267760784655756, 'x4 x7': 1.6676014142415467, 'x4 x8': 74.93556900334914, 'x4 x9': 93.24149029940865, 'x4 x10': 153.39666354755764, 'x4 x11': -617.5801675982945, 'x4 x12': 6.232282441722958, 'x5^2': 266.7591273422475, 'x5 x6': 0.0, 'x5 x7': 0.0, 'x5 x8': 29.844448759574767, 'x5 x9': 0.0, 'x5 x10': 0.0, 'x5 x11': 0.0, 'x5 x12': -22.41999333591723, 'x6^2': 120.27506226098349, 'x6 x7': 0.0, 'x6 x8': 0.0, 'x6 x9': 0.0, 'x6 x10': 67.00730147632818, 'x6 x11': 0.0, 'x6 x12': 0.9775839777474675, 'x7^2': 53.38114621791787, 'x7 x8': -159.67227250161588, 'x7 x9': 0.0, 'x7 x10': 385.7538095990695, 'x7 x11': -617.5801675982945, 'x7 x12': -5.556414435513489, 'x8^2': 74.93556900334914, 'x8 x9': 0.0, 'x8 x10': 0.0, 'x8 x11': 0.0, 'x8 x12': -20.973480235350387, 'x9^2': -261.51266913388804, 'x9 x10': 0.0, 'x9 x11': 0.0, 'x9 x12': 47.03247753124699, 'x10^2': -118.48446765432082, 'x10 x11': 0.0, 'x10 x12': 10.61475067689048, 'x11^2': -617.5801675982945, 'x11 x12': -63.06818177348037, 'x12^2': -0.17847495248082623}

# %% [markdown]
# ## Log transformation regression (Simple)

# %%
def log_regressor(X, y, regression_class):
    
    y=np.log(y)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=23)

    lin_reg = regression_class
    lin_reg.fit(X_train, y_train)
    
    intercept = lin_reg.intercept_
    coefficients = dict(zip(X.columns, lin_reg.coef_))
    
    #note that having carried out a log transformation, our linear equation is no longer
    # y = mx + c, but is instead y=exp(c)exp(mx), where and c and m are the above printed parameters
    
#     lin_reg = TransformedTargetRegressor(regressor=regression_class, func=np.log, inverse_func=np.exp)
#     lin_reg.fit(X_train, y_train)
#     print(lin_reg.regressor_.intercept_)
#     print(lin_reg.regressor_.coef_)

    preds_train = lin_reg.predict(X_train)
    preds_test = lin_reg.predict(X_test)
    preds_all = lin_reg.predict(X)
    residuals = y - preds_all
    
    return X_train, X_test, y_train, y_test, preds_train, preds_test, preds_all, residuals, coefficients, intercept

# calculate regression errors
def log_reg_errors(y_test, preds_test):
    
    mae = mean_absolute_error(np.exp(y_test), np.exp(preds_test))
    rmse = mean_squared_error(np.exp(y_test), np.exp(preds_test), squared=False)
    r2 = r2_score(y_test, preds_test)
    
    return mae, rmse, r2

#plot of regression and it's assumptions.
# func argument can be the regressor function, or any other function. log_regressor and lasso_regressor are others.
def log_reg_plots(func, string_description):
    
    X_train, X_test, y_train, y_test, preds_train, preds_test, preds_all, residuals, coefficients, intercept = func

    mae, rmse, r2 = log_reg_errors(y_test, preds_test)
    
    fig, axes = plt.subplots(1,3,figsize=(15,6))

    fig.suptitle("Regression: {}\n \
                 MAE = £{} \n \
                 RMSE = £{} \n \
                 R2 = {}".format(string_description, round(mae, 1), round(rmse, 1), round(r2,3)))
    
    sns.histplot(residuals, kde = True, bins = 100, ax=axes[0])
    axes[0].set_title("Distribution of log(residuals)")

    qqplot(residuals, line='45', fit=True, ax=axes[1])
    axes[1].set_title("Q-Q plot")

    sns.scatterplot(x=preds_all, y=residuals, ax=axes[2], alpha = 0.5, s=15)
    plt.hlines(0, min(preds_all), max(preds_all), linestyles='dashed', colors='red')
    axes[2].set_xlabel("predicted price")
    axes[2].set_ylabel("residuals")
    axes[2].set_title("residuals vs price predicted")
    
    plt.tight_layout()
    
    return coefficients, intercept

# %%
X = pots_reg[['height']]
y = pots_reg['price']

coefficients, intercept = log_reg_plots(log_regressor(X, y, LinearRegression()), 'simple linear LOG regression (height)')

# %% [markdown]
# ## Log transformation regression (multiple)

# %%
X = pots_reg[['height', 'materials_Earthenware', 'materials_Porcelain',
       'materials_Stoneware', 'technique_Thrown', 'firing_Gas', 'firing_Raku',
       'firing_Wood', 'decoration_Lustre', 'decoration_Sgraffito',
       'decoration_Slip decoration', 'decoration_Terra Sigillata', 'length']]
y = pots_reg['price']

coefficients, intercept = log_reg_plots(log_regressor(X, y, LinearRegression()), 'simple linear LOG regression (height)')

# %% [markdown]
# ## Log transformation, multiple regression, polynomial order = 2

# %%
X = pots_reg[['height', 'materials_Earthenware', 'materials_Porcelain',
       'materials_Stoneware', 'technique_Thrown', 'firing_Gas', 'firing_Raku',
       'firing_Wood', 'decoration_Lustre', 'decoration_Sgraffito',
       'decoration_Slip decoration', 'decoration_Terra Sigillata', 'length']]
y = pots_reg['price']

# Define a PolynomialFeatures transformer with degree=2 and include_bias=False
poly = PolynomialFeatures(degree=2, include_bias=False)

# Fit transform the training data
X = poly.fit_transform(X)

X = pd.DataFrame(data=X, columns=poly.get_feature_names())

coefficients, intercept = log_reg_plots(log_regressor(X, y, LinearRegression()), 'all independent variables')

# %% [markdown]
# ## With Lasso

# %%
X = pots_reg[['height', 'materials_Earthenware', 'materials_Porcelain',
       'materials_Stoneware', 'technique_Thrown', 'firing_Gas', 'firing_Raku',
       'firing_Wood', 'decoration_Lustre', 'decoration_Sgraffito',
       'decoration_Slip decoration', 'decoration_Terra Sigillata', 'length']]
y = pots_reg['price']

# Define a PolynomialFeatures transformer with degree=2 and include_bias=False
poly = PolynomialFeatures(degree=2, include_bias=False)

# Fit transform the training data
X_poly = poly.fit_transform(X)
X_poly = pd.DataFrame(data=X_poly, columns=poly.get_feature_names(X.columns))

coefficients, intercept = log_reg_plots(log_regressor(X_poly, y, LassoCV()), 'all independent variables')

# %%
selected_coef_={x:round(y, 2-int(np.floor(np.log10(abs(y))))-1) for x,y in coefficients.items() if y!=0}
print('intercept:', round(intercept, 2))
selected_coef_
# Out:
# intercept: 3.72
# {'height': 0.067,
#  'height^2': -0.00093,
#  'height materials_Porcelain': 0.0043,
#  'height materials_Stoneware': 0.014,
#  'height length': 0.0015,
#  'materials_Earthenware length': -0.0057,
#  'materials_Stoneware length': 0.00013,
#  'technique_Thrown length': -0.0065,
#  'length^2': 0.0016}

# %% [markdown]
# Final equation: $$ Price = e^{3.72}.exp(0.067height - 0.00093height^2 + 0.0015height.length \\
#                                 + 0.0016length^2 + 0.014height.Stoneware + 0.0043height.Porcelain \\
#                                 - 0.0057length.Earthenware + 0.00013length.Stoneware - 0.0065length.Thrown) $$
